# %%
# Session 12: Numerical Variables
# Load dataset and preview numeric column ranges
import pandas as pd
# Load the dataset
df = pd.read_csv("/Users/yikib/student-performance-prediction-ml/data/raw/student-mat.csv", sep=";")


# Preview the first five rows
print("Dataset loaded successfully.")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully.
# Shape: (395, 33)

# %%
display(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
# Identify numeric columns
num_cols = df.select_dtypes(include="number").columns.tolist()
print("Number of numeric columns:", len(num_cols))
print("Numeric columns:")
print(num_cols)
# Out:
# Number of numeric columns: 16
# Numeric columns:
# ['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']

# %%
# Clean numeric summary table
numeric_summary = df[num_cols].agg(["min", "max", "mean"]).T
numeric_summary = numeric_summary.round(2)
display(numeric_summary)
# Out:
#              min   max   mean
# age         15.0  22.0  16.70
# Medu         0.0   4.0   2.75
# Fedu         0.0   4.0   2.52
# traveltime   1.0   4.0   1.45
# studytime    1.0   4.0   2.04
# failures     0.0   3.0   0.33
# famrel       1.0   5.0   3.94
# freetime     1.0   5.0   3.24
# goout        1.0   5.0   3.11
# Dalc         1.0   5.0   1.48
# Walc         1.0   5.0   2.29
# health       1.0   5.0   3.55
# absences     0.0  75.0   5.71
# G1           3.0  19.0  10.91
# G2           0.0  19.0  10.71
# G3           0.0  20.0  10.42

# %%
# Save numeric summary to reports folder
import os
os.makedirs("reports", exist_ok=True)
numeric_summary.to_csv("reports/session12_numeric_summary.csv")
print("Saved: reports/session12_numeric_summary.csv")
# Out:
# Saved: reports/session12_numeric_summary.csv
