# %%
# # Session 13: Exploratory Grade Analysis
# This notebook creates a histogram of the final grade variable `G3`.
# Main output:
# - `figures/grade_distribution.png`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
os.makedirs("figures", exist_ok=True)
print("figures folder is ready.")
# Out:
# figures folder is ready.

# %%
df = pd.read_csv("/Users/yikib/student-performance-prediction-ml/data/preprocessed/student_cleaned_ml_ready.csv")
print("Dataset loaded successfully.")
print("Shape:", df.shape)
df.head()

#/content/drive/MyDrive/GSSRP_Project/student_cleaned_ml_ready.csv
# Out:
# Dataset loaded successfully.
# Shape: (395, 42)
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  \
# 0       0    0   18        0        0        0     4     4           2
# 1       0    0   17        0        0        1     1     1           1
# 2       0    0   15        0        1        1     1     1           1
# 3       0    0   15        0        0        1     4     2           1
# 4       0    0   16        0        0        1     3     3           1
#
#    studytime  ...  Mjob_teacher  Fjob_health  Fjob_other  Fjob_services  \
# 0          2  ...             0            0           0              0
# 1          2  ...             0            0           1              0
# 2          2  ...             0            0           1              0
# 3          3  ...             0            0           0              1
# 4          2  ...             0            0           1              0
#
# ...

# %%
print("Dataset columns:")
print(df.columns.tolist())
if "G3" in df.columns:
  print("\nG3 column exists. Ready to plot.")
else:
  print("\nERROR: G3 column was not found.")
# Out:
# Dataset columns:
# ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'at_risk', 'Mjob_health', 'Mjob_other', 'Mjob_services', 'Mjob_teacher', 'Fjob_health', 'Fjob_other', 'Fjob_services', 'Fjob_teacher', 'reason_home', 'reason_other', 'reason_reputation', 'guardian_mother', 'guardian_other']
#
# ERROR: G3 column was not found.

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
df = pd.read_csv("/Users/yikib/student-performance-prediction-ml/data/raw/student-mat.csv", sep = ";")

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
print("Dataset columns:")
print(df.columns.tolist())
if "G3" in df.columns:
  print("\nG3 column exists. Ready to plot.")
else:
  print("\nERROR: G3 column was not found.")
# Out:
# Dataset columns:
# ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']
#
# G3 column exists. Ready to plot.

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["G3"], bins=20, kde=True)
plt.title("Distribution of Final Grade (G3)")
plt.xlabel("G3")

#GSSRP 2026 - Kean University | Predicting Student Performance Using Machine Learning Session 13/48 - Week 2
plt.ylabel("Count")
plt.savefig("figures/grade_distribution.png", bbox_inches="tight", dpi=300)
plt.show()
print("Histogram saved as: figures/grade_distribution.png")
# Out:
# Histogram saved as: figures/grade_distribution.png

# %%
os.path.exists("figures/grade_distribution.png")
# Out:
# True

# %%
from IPython.display import Image, display
display(Image(filename="figures/grade_distribution.png"))

# %% [markdown]
# ## Prompt-Engineered Explanation Task
# **Role:** Act as an EDA assistant.
# **Task:** Interpret a final-grade histogram for an education dataset.
# **Requirements:**
# 1. Describe the shape of the distribution.
# 2. Note whether there is a spike at zero.
# 3. Discuss implications for the pass/fail threshold.
# **Output format:**
# - Summary
# - Interpretation
# - Recommendation

# %% [markdown]
# ## Prompt-Engineered Explanation Task
# **Role:** Act as an EDA assistant.
# **Task:** Interpret a final-grade histogram for an education dataset.
# **Requirements:**
# 1. Describe the shape of the distribution.
# 2. Note whether there is a spike at zero.
# 3. Discuss implications for the pass/fail threshold.
# **Output format:**
# - Summary
# - Interpretation
# - Recommendation
# ---
# ## Student Response
# ### Summary
# The histogram shows the distribution of the final grade variable `G3`. Most
# students appear to be concentrated in the middle range of the grade scale, while
# fewer students appear at the very low and very high ends. The graph helps us
# understand whether final grades are balanced, skewed, or concentrated around
# certain values.
# ### Interpretation
# The distribution should be examined for its overall shape, including whether it is
# approximately symmetric, left-skewed, right-skewed, or clustered around a specific
# grade range. A visible spike at `G3 = 0` may indicate a special group of students
# whose final grade was recorded as zero. This could represent students who did not
# complete the course, missed the final exam, withdrew, or had serious academic
# problems. Because zero grades may have a different meaning from ordinary low
# grades, they should be investigated carefully before building prediction models.
# ### Recommendation
# Before choosing a pass/fail threshold, the zero-grade group should be reviewed
# carefully. If the project defines passing as `G3 >= 10`, then students with `G3 <
# 10` would be labeled as not passing. However, if many zero grades represent missing
# work, withdrawal, or administrative cases, the research team should decide whether
# to keep them, remove them, or analyze them separately. This decision should be
# documented because it affects the target variable, model evaluation, and
# interpretation of student risk.

# %% [markdown]
# ## Why This Prompt Matters
# This prompt helps convert a visual plot into a research interpretation. Instead of
# only creating a histogram, students explain what the histogram means for the
# machine learning problem. This is important because the distribution of `G3`
# affects target-variable design, pass/fail threshold selection, and model
# evaluation.

# %%
# Session 14 - Study Time and Performance Analysis
# Google Colab version only
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Create the figures folder if it does not already exist
os.makedirs("figures", exist_ok=True)
# Check that df exists
try:
  df
except NameError:
  raise NameError(
  "df is not loaded. Run the data-loading cell first before running Session14."
  )
# Check that the required columns exist
required_columns = ["studytime", "G3"]
missing_columns = [col for col in required_columns if col not in df.columns]
if missing_columns:
  raise KeyError(
  f"Missing required columns: {missing_columns}. "
  f"Available columns are: {list(df.columns)}"
  )
# Make sure studytime and G3 are numeric
df["studytime"] = pd.to_numeric(df["studytime"], errors="coerce")

#GSSRP 2026 - Kean University | Predicting Student Performance Using Machine Learning Session 14/48 - Week 2
df["G3"] = pd.to_numeric(df["G3"], errors="coerce")
# Remove rows with missing studytime or G3 values
plot_df = df.dropna(subset=["studytime", "G3"]).copy()
# Convert studytime to integer groups
plot_df["studytime"] = plot_df["studytime"].astype(int)
# Print basic checks
print("Rows used in this analysis:", len(plot_df))
print("\nNumber of students in each study-time group:")
print(plot_df["studytime"].value_counts().sort_index())
# Compute and print mean final grade by study-time group
print("\nMean final grade by study-time group:")
mean_grades = plot_df.groupby("studytime")["G3"].mean().round(2)
print(mean_grades)
# Create the boxplot
plt.figure(figsize=(7, 5))
sns.boxplot(x="studytime", y="G3", data=plot_df)
plt.title("Final Grade by Study Time")
plt.xlabel("Study Time Group")
plt.ylabel("Final Grade (G3)")
# Save the figure
plt.savefig("figures/studytime_vs_grade.png", bbox_inches="tight", dpi=300)
# Show the plot in Colab
plt.show()
print("\nSaved figure: figures/studytime_vs_grade.png")
# Out:
# Rows used in this analysis: 395
#
# Number of students in each study-time group:
# studytime
# 1    105
# 2    198
# 3     65
# 4     27
# Name: count, dtype: int64
#
# Mean final grade by study-time group:
# studytime
# 1    10.05
# 2    10.17
# 3    11.40
# 4    11.26
# Name: G3, dtype: float64
# Saved figure: figures/studytime_vs_grade.png

# %%
print(df.groupby("failures")["G3"].mean())
sns.scatterplot(x="absences", y="G3", data=df, alpha=0.5)
plt.title("Final Grade vs Absences")
plt.savefig("figures/absences_vs_grade.png", bbox_inches="tight")
plt.show()
# Out:
# failures
# 0    11.253205
# 1     8.120000
# 2     6.235294
# 3     5.687500
# Name: G3, dtype: float64

# %%
import os
print("Current Working Directory:", os.getcwd())
print("Does figures directory exist here?:", os.path.exists("figures"))
# Out:
# Current Working Directory: c:\Users\yikib\student-performance-prediction-ml\notebooks
# Does figures directory exist here?: True

# %% [markdown]
# ## Session 14 Finding: Study Time and Final Grade
# The figure `studytime_vs_grade.png` compares final grade `G3` across the four
# `studytime` groups.
# The boxplot and mean-grade comparison suggest that study time may be associated
# with final grade. Students in higher study-time groups may show higher average
# final grades than students in the lowest study-time group. However, the pattern
# should be checked carefully because the trend may not be perfectly monotonic across
# all four study-time levels.
# This analysis does not prove that more study time causes higher grades. The plot
# only shows an association. Other factors, such as prior grades, absences, failures,
# motivation, family support, and school support, may also influence final grade.
# A useful follow-up would be to compare study time with other predictors in a
# regression model or machine learning model to evaluate whether `studytime` remains
# important after accounting for other variables.

# %%
# Session 16: Family and school-support analysis
support_features = ["schoolsup", "famsup", "higher"]

for col in support_features:
    print("=" * 60)
    print(f"Final-grade summary by {col}")
    summary = (
        df.groupby(col)["G3"]
        .agg(
            student_count="count",
            mean_G3="mean",
            median_G3="median",
            standard_deviation="std"
        )
        .round(2)
    )
    display(summary)

# %%
# Compare the mean grade of the yes and no groups
support_differences = []

for col in ["schoolsup", "famsup", "higher"]:
    means = df.groupby(col)["G3"].mean()
    no_mean = means.get("no")
    yes_mean = means.get("yes")
    support_differences.append({
        "feature": col,
        "mean_G3_no": no_mean,
        "mean_G3_yes": yes_mean,
        "difference_yes_minus_no": yes_mean - no_mean
    })

support_difference_table = pd.DataFrame(support_differences).round(2)
display(support_difference_table)

# %% [markdown]
# # Session 16: Family and School-Support Analysis
# ## Purpose
# This exploratory analysis examines how school support, family support, and
# students' aspirations for higher education are associated with final academic
# performance. Final performance is measured using G3, the final course grade.
# ## Variables
#
# GSSRP 2026 - Kean University | Predicting Student Performance Using Machine Learning Session 16/48 - Week 2
# - **schoolsup:** Whether the student receives additional educational support from
# the school.
# - **famsup:** Whether the student receives educational support from the family.
# - **higher:** Whether the student intends to pursue higher education.
# - **G3:** Final course grade.
# ## Numerical Results
# ### School Support
# - Mean G3 without school support: ______
# - Mean G3 with school support: ______
# - Difference, yes minus no: ______
# - Number of students without school support: ______
# - Number of students with school support: ______
# ### Family Support
# - Mean G3 without family support: ______
# - Mean G3 with family support: ______
# - Difference, yes minus no: ______
# - Number of students without family support: ______
# - Number of students with family support: ______
# ### Higher-Education Aspiration
# - Mean G3 without higher-education aspiration: ______
# - Mean G3 with higher-education aspiration: ______
# - Difference, yes minus no: ______
# - Number of students without higher-education aspiration: ______
# - Number of students with higher-education aspiration: ______
# ## Summary
# Students receiving school support had a mean G3 of ______, compared with ______ for
# students not receiving school support.
# Students receiving family support had a mean G3 of ______, compared with ______ for
# students not receiving family support.
# Students intending to pursue higher education had a mean G3 of ______, compared
# with ______ for students not intending to pursue higher education.
# ## Interpretation
# The school-support comparison showed that students receiving school support had a
# higher/lower/similar average final grade. If the supported group had a lower
# average, this should not be interpreted as evidence that school support reduced
# student performance. Students with existing academic difficulties may have been
# more likely to receive support.
# The family-support comparison showed a positive/negative/limited descriptive
# relationship with final grades.
# The higher-education comparison showed a positive/negative/limited descriptive
# relationship with final grades.
# The most counter-intuitive result was that ______.
# A possible explanation is that ______.
#
# GSSRP 2026 - Kean University | Predicting Student Performance Using Machine Learning Session 16/48 - Week 2
# ## Confounding Considerations
# Prior academic performance may affect both whether a student receives support and
# the student's final grade. Other possible confounding variables include previous
# failures, attendance, study time, motivation, learning difficulties, family
# background, and socioeconomic conditions.
# These results describe associations only and do not establish causal effects.
# ## Recommendations
# - Retain **schoolsup** because it may identify students receiving academic
# intervention or students with greater prior academic need.
# - Retain **famsup** because it provides potentially useful family-context
# information.
# - Retain **higher** because educational aspiration may reflect motivation,
# expectations, and future academic goals.
# - Evaluate all three variables later in multivariable models rather than relying
# only on unadjusted group means.
# ## Reflection
# If school support is associated with lower grades, a likely confounding explanation
# is that students who were already struggling academically were more likely to
# receive support. Their lower final grades may reflect prior academic risk rather
# than a harmful effect of the support itself.
# ## Conclusion
# School support, family support, and higher-education aspiration showed different
# descriptive relationships with final grades. The findings justify retaining all
# three features for later analysis, while interpreting them cautiously because of
# possible confounding and selection effects.
