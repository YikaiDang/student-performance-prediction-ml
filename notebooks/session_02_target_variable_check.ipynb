# %%
# Session 2 - quick sanity check on the target variable G3
import pandas as pd
import zipfile
import requests
from io import BytesIO

# UCI Student Performance dataset ZIP file

# Session 2 - quick sanity check on the target variable G3

# Define the direct path to your CSV file in Google Drive
file_path = "/content/drive/MyDrive/GSSRP_Project/student-mat.csv"

# Load the CSV directly (specifying the semicolon separator used by UCI datasets)
df = pd.read_csv(file_path, sep=';')

# Quick sanity checks
print("Rows, columns:", df.shape)
print(df[['G1', 'G2', 'G3']].describe())

df['at_risk'] = (df['G3'] < 10).astype(int)
print(df['at_risk'].value_counts())
# Out:
# Rows, columns: (395, 33)
#                G1          G2          G3
# count  395.000000  395.000000  395.000000
# mean    10.908861   10.713924   10.415190
# std      3.319195    3.761505    4.581443
# min      3.000000    0.000000    0.000000
# 25%      8.000000    9.000000    8.000000
# 50%     11.000000   11.000000   11.000000
# 75%     13.000000   13.000000   14.000000
# max     19.000000   19.000000   20.000000
# at_risk
# 0    265
# 1    130
# Name: count, dtype: int64

# %% [markdown]
# Scientific research paper:  **Systematic Literature Review of Student’ Performance
# Prediction Using Machine Learning Techniques**
#
# Researchers looked at a bunch of EDM studies from 2009 to 2021
# Using a bunch of metrics for the data that was used for all of the studies the researchers decided that machine learning does work for analyzing mass data and predicting at-risk students. So education and EDM in general are benefitting a lot from ML.
#
# --------------
#
# Supervised learning is where data is labeled which makes the model predict a specific variable. Classification and regression are the fundamental examples of supervised learning
#
# Unsupervised learning is where the data does not have any labels so we force the model to work blindly which allows us to see how the model truly works in terms of its patterns and structure.
# K-means clustering and image compression.
#
#
# ----------------
#
# Libraries: pandas, polars, os, regex, numpy, pytorch, matplotlib
#
# Functions eliminate redundancy in programs, they take an input and produce an output
#
# A dataframe is a versatile structure in Python for holding data that can be modified.

# %%
df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 at_risk
# 0  ...        3     4     1     1       3        6   5   6   6       1
# ...

# %%
summary = pd.DataFrame({
"dtype": df.dtypes.astype(str),
"n_unique": df.nunique(),
"n_missing": df.isna().sum(),
})

print(summary)
# Out:
#              dtype  n_unique  n_missing
# school      object         2          0
# sex         object         2          0
# age          int64         8          0
# address     object         2          0
# famsize     object         2          0
# Pstatus     object         2          0
# Medu         int64         5          0
# Fedu         int64         5          0
# Mjob        object         5          0
# Fjob        object         5          0
# reason      object         4          0
# guardian    object         3          0
# traveltime   int64         4          0
# studytime    int64         4          0
# failures     int64         4          0
# schoolsup   object         2          0
# famsup      object         2          0
# paid        object         2          0
# activities  object         2          0
# nursery     object         2          0
# higher      object         2          0
# internet    object         2          0
# ...

# %%
summary = pd.DataFrame({
"dtype": df.dtypes.astype(str),
"n_unique": df.nunique(),
"n_missing": df.isna().sum(),
})

display(summary)
# Out:
#              dtype  n_unique  n_missing
# school      object         2          0
# sex         object         2          0
# age          int64         8          0
# address     object         2          0
# famsize     object         2          0
# Pstatus     object         2          0
# Medu         int64         5          0
# Fedu         int64         5          0
# Mjob        object         5          0
# Fjob        object         5          0
# reason      object         4          0
# guardian    object         3          0
# traveltime   int64         4          0
# studytime    int64         4          0
# failures     int64         4          0
# schoolsup   object         2          0
# famsup      object         2          0
# paid        object         2          0
# activities  object         2          0
# nursery     object         2          0
# higher      object         2          0
# internet    object         2          0
# ...

# %%
summary = pd.DataFrame({
"variable": df.columns,
"dtype": df.dtypes.astype(str).values,
"n_unique": df.nunique().values,
"n_missing": df.isna().sum().values,
})
display(summary)
# Out:
#       variable   dtype  n_unique  n_missing
# 0       school  object         2          0
# 1          sex  object         2          0
# 2          age   int64         8          0
# 3      address  object         2          0
# 4      famsize  object         2          0
# 5      Pstatus  object         2          0
# 6         Medu   int64         5          0
# 7         Fedu   int64         5          0
# 8         Mjob  object         5          0
# 9         Fjob  object         5          0
# 10      reason  object         4          0
# 11    guardian  object         3          0
# 12  traveltime   int64         4          0
# 13   studytime   int64         4          0
# 14    failures   int64         4          0
# 15   schoolsup  object         2          0
# 16      famsup  object         2          0
# 17        paid  object         2          0
# 18  activities  object         2          0
# 19     nursery  object         2          0
# ...

# %%
print(df.columns)
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'at_risk'],
#       dtype='object')

# %%
df["passed"] = (df["G3"] >= 10).astype(int)
print(df["passed"].value_counts())
print("Regression target: G3")
print("Classification target: passed (1 if G3>=10 else 0)")
# Out:
# passed
# 1    265
# 0    130
# Name: count, dtype: int64
# Regression target: G3
# Classification target: passed (1 if G3>=10 else 0)

# %%
df[["G3", "passed"]].head()
# Out:
#    G3  passed
# 0   6       0
# 1   6       0
# 2  10       1
# 3  15       1
# 4  10       1

# %% [markdown]
# # Target Definition Note
# ## Regression Target
# The regression target is `G3`, which represents the student's final grade. This
# target will be used when the model predicts a numeric final grade.
# ## Classification Target
# The classification target is `passed`. This target converts the final grade into a
# binary outcome.
# The classification rule is:
# passed = 1 if G3 >= 10
# passed = 0 if G3 < 10
# This means that students with final grades of 10 or higher are labeled as passing,
# while students with final grades below 10 are labeled as not passing.
# ## Chosen Threshold
# The chosen threshold is `G3 >= 10` for passing. Students with `G3 < 10` are
# considered at risk or not passing.
# ## Limitation
# One limitation of this threshold is that it creates a hard cutoff. For example, a
# student with `G3 = 9` is labeled as not passing, while a student with `G3 = 10` is
# labeled as passing. However, these two students may have very similar academic
# performance.
# ## Final Decision
# For the first version of the project, we will keep the `G3 >= 10` threshold because
# it is simple, clear, and easy to explain. However, we will document its limitation
# and may compare it with other thresholds, such as `G3 < 12`, in a later version of
# the project.

# %%
print(df.shape)
print(df.info())
print(df.describe(include="all").T)
# Out:
# (395, 35)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 35 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
print("Dataset shape:")
print(df.shape)
print("\nDataset information:")
df.info()
print("\nSummary statistics:")
display(df.describe(include="all").T)
# Out:
# Dataset shape:
# (395, 35)
#
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 35 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
# ...

# %%
# The inspection results show the number of rows and columns in the dataset, the data
# type of each variable, and whether any variables contain missing values. The
# summary statistics help us identify the range, average, and distribution of
# numerical variables, as well as the most common values in categorical variables.

# This step is important because machine learning models require clean and well-
# understood data before training.
